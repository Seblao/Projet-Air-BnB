# %% [markdown]
# <a href="https://colab.research.google.com/github/Seblao/Projet-Air-BnB/blob/main/1_1_Pandas_Introduction_to_DataFrames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mission 1
#
# ![](https://i.imgur.com/Ax3pp2A.png)
#
#
# Create a "fruit" dataframe that reflects the above example **using a list** data structure
#
# [This resource could help you](https://datatofish.com/list-to-dataframe/).

# %%
import pandas as pd

data = [[30, 21]]
columns = ['Apples', 'Bananas']

df_fruit = pd.DataFrame(data, columns=columns)
df_fruit
# Out:
#    Apples  Bananas
# 0      30       21

# %% [markdown]
# # Mission 2
#
# Create a "fruit_vendors" dataframe that reflects the below example **using a dictionary** data structure
#
# ![](https://i.imgur.com/CHPn7ZF.png)
#
# [This resource could help you.](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.from_dict.html)

# %%
data = {
    'Apples': [35, 41],
    'Bananas': [21, 34]
}

fruit_vendors = pd.DataFrame(data, index=['2017 Sales', '2018 Sales'])
fruit_vendors
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %% [markdown]
# # Mission 3
#
# Use a loop to display the values from each column in the dataframe from mission 2.
#
# [This resource could help you](https://apprendrepython.com/pandas-iterate-dataframe-avec-la-boucle-for/)

# %%
for column in fruit_vendors.columns :

  print(f"{column}:")
  print(fruit_vendors[column].values)
  print()
# Out:
# Apples:
# [35 41]
#
# Bananas:
# [21 34]

# %% [markdown]
# # Mission 4
#
# Delete the first row of the dataframe from mission 2
#
# [This resource could help you.](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)

# %%
df_fruit_vendors = fruit_vendors.drop('2017 Sales')

df_fruit_vendors
# Out:
#             Apples  Bananas
# 2018 Sales      41       34

# %% [markdown]
# # Mission 5
#
# Delete the first column from the dataframe from mission 2.

# %%
df_fruit_vendors = fruit_vendors.drop(fruit_vendors.columns[0], axis=1)

df_fruit_vendors
# Out:
#             Bananas
# 2017 Sales       21
# 2018 Sales       34
