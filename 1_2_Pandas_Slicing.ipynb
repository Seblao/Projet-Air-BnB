# %% [markdown]
# <a href="https://colab.research.google.com/github/Seblao/Projet-Air-BnB/blob/main/1_2_Pandas_Slicing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mission 1
#
# Display the following information [for this dataset](https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user).
# - The last 5 rows
# - The first 5 rows
# - The type of each column
#
# Note : start coding something by typing `pd.read_csv()` and explore the different options available, especially the `sep` parameter.

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user')
df
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# ..                            ...
# 937        939|26|F|student|33319
# 938  940|32|M|administrator|02215
# 939        941|20|M|student|97229
# 940      942|48|F|librarian|78209
# 941        943|22|M|student|77841
#
# [942 rows x 1 columns]

# %%
df.tail()
# Out:
#           1|24|M|technician|85711
# 937        939|26|F|student|33319
# 938  940|32|M|administrator|02215
# 939        941|20|M|student|97229
# 940      942|48|F|librarian|78209
# 941        943|22|M|student|77841

# %%
df.head()
# Out:
#    1|24|M|technician|85711
# 0       2|53|F|other|94043
# 1      3|23|M|writer|32067
# 2  4|24|M|technician|43537
# 3       5|33|F|other|15213
# 4   6|42|M|executive|98101

# %%
df.dtypes
# Out:
# 1|24|M|technician|85711    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 942 entries, 0 to 941
# Data columns (total 1 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   1|24|M|technician|85711  942 non-null    object
# dtypes: object(1)
# memory usage: 7.5+ KB

# %% [markdown]
# # Mission 2
#
# Display the first 10 rows [in the following file](https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/drinks.csv)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/drinks.csv')
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# 2                             0.7         Africa
# 3                            12.4         Europe
# 4                             5.9         Africa
# ..                            ...            ...
# 188                           7.7  South America
# 189                           2.0           Asia
# 190                           0.1           Asia
# 191                           2.5         Africa
# 192                           4.7         Africa
#
# [193 rows x 6 columns]

# %%
df.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# 3                          12.4         Europe
# 4                           5.9         Africa
# 5                           4.9  North America
# 6                           8.3  South America
# 7                           3.8         Europe
# 8                          10.4        Oceania
# 9                           9.7         Europe

# %% [markdown]
# Set the "country" column as the index for the dataframe, using `set_index` method.

# %%
df.set_index('country', inplace=True)
df
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol      continent
# country
# Afghanistan                           0.0           Asia
# Albania                               4.9         Europe
# Algeria                               0.7         Africa
# Andorra                              12.4         Europe
# Angola                                5.9         Africa
# ...                                   ...            ...
# Venezuela                             7.7  South America
# Vietnam                               2.0           Asia
# Yemen                                 0.1           Asia
# Zambia                                2.5         Africa
# Zimbabwe                              4.7         Africa
#
# [193 rows x 5 columns]

# %% [markdown]
# # Mission 3
#
# Access the values of the row for **Zimbabwe** (use the index value)

# %%
zimbabwe_row = df.loc['Zimbabwe']
zimbabwe_row
# Out:
# beer_servings                       64
# spirit_servings                     18
# wine_servings                        4
# total_litres_of_pure_alcohol       4.7
# continent                       Africa
# Name: Zimbabwe, dtype: object

# %% [markdown]
# # Mision 4
#
# Display only the "continent" column value for the country **Zimbabwe**.

# %%
columns_continent = df.loc['Zimbabwe', 'continent']
columns_continent
# Out:
# 'Africa'

# %% [markdown]
# # Mission 5
#
# Rename the columns [of this dataset](https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv), try using the following 2 different methods to achieve this:
# - Setting column names directly when reading the file
# - Editing after creating the dataframe ([This resource could be useful](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html))

# %%
df
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol      continent
# country
# Afghanistan                           0.0           Asia
# Albania                               4.9         Europe
# Algeria                               0.7         Africa
# Andorra                              12.4         Europe
# Angola                                5.9         Africa
# ...                                   ...            ...
# Venezuela                             7.7  South America
# Vietnam                               2.0           Asia
# Yemen                                 0.1           Asia
# Zambia                                2.5         Africa
# Zimbabwe                              4.7         Africa
#
# [193 rows x 5 columns]

# %%
# Aucune idée

# %%
df.rename(columns={'beer_servings':'beer', 'spirit_servings': 'spirit', 'wine_servings': 'wine', 'total_litres_of_pure_alcohol' : 'pur_alcohol', 'continent': 'World'})
# Out:
#              beer  spirit  wine  pur_alcohol          World
# country
# Afghanistan     0       0     0          0.0           Asia
# Albania        89     132    54          4.9         Europe
# Algeria        25       0    14          0.7         Africa
# Andorra       245     138   312         12.4         Europe
# Angola        217      57    45          5.9         Africa
# ...           ...     ...   ...          ...            ...
# Venezuela     333     100     3          7.7  South America
# Vietnam       111       2     1          2.0           Asia
# Yemen           6       0     0          0.1           Asia
# Zambia         32      19     4          2.5         Africa
# Zimbabwe       64      18     4          4.7         Africa
#
# [193 rows x 5 columns]

# %%
df
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol      continent
# country
# Afghanistan                           0.0           Asia
# Albania                               4.9         Europe
# Algeria                               0.7         Africa
# Andorra                              12.4         Europe
# Angola                                5.9         Africa
# ...                                   ...            ...
# Venezuela                             7.7  South America
# Vietnam                               2.0           Asia
# Yemen                                 0.1           Asia
# Zambia                                2.5         Africa
# Zimbabwe                              4.7         Africa
#
# [193 rows x 5 columns]

# %% [markdown]
# # Mission 6
#
# Select the first 3 rows and all the columns of the dataframe using iloc

# %%
df.iloc[:3]
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa

# %% [markdown]
# # Mission 7
#
# Achieve the same result as in mission 6 by using loc

# %%
df.loc[df.index[:3]]
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
